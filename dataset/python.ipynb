# %%
import pandas as pd
df = pd.read_csv("sales_dataset.csv")
df.head()
# Out:
#    CustomerId                OrderDate SalesOrderNumber    Subtotal  \
# 0       29847  2008-06-01 00:00:00.000          SO71774    880,3484
# 1       29847  2008-06-01 00:00:00.000          SO71774    880,3484
# 2       30072  2008-06-01 00:00:00.000          SO71776       78,81
# 3       30113  2008-06-01 00:00:00.000          SO71780  38418,6895
# 4       30113  2008-06-01 00:00:00.000          SO71780  38418,6895
#
#       TaxAmt   Freight    TotalDue  ProductID  \
# 0    70,4279   22,0087     972,785        836
# 1    70,4279   22,0087     972,785        822
# 2     6,3048    1,9703     87,0851        907
# 3  3073,4952  960,4672  42452,6519        905
# 4  3073,4952  960,4672  42452,6519        983
#
#                         ProductName  OrderQty  LineTotal
# 0      ML Road Frame-W - Yellow, 48         1    356.898
# 1      ML Road Frame-W - Yellow, 38         1    356.898
# 2                       Rear Brakes         1     63.900
# ...
